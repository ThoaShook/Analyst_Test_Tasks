# %%
# import python library packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")

# %%
# upload Tapestry_patients file
# explore the first 800 rows
df = pd.read_csv('Analyst_Test_Tapestry_patients.csv')
df.head(800)
# Out:
#     Patient Unique ID  Birth Date   PRS   Gender Subzone  Chronic Conditions
# 0            67130544   5/26/1974   0.70    Male      1d                 0.0
# 1            73838640   8/31/1924   1.00    Male   4a_FO                 5.0
# 2            73576382    2/8/1954   1.00  Female   2a_FO                 6.0
# 3            74030096   3/15/1934   1.00  Female   2a_FO                 6.0
# 4            73981356   5/18/1938   1.00  Female   2a_FO                 7.0
# ..                ...         ...    ...     ...     ...                 ...
# 795          74549412  10/11/1945   1.00    Male   1a_FO                 7.0
# 796          73705884    5/6/1940   1.00  Female   1a_FO                 4.0
# 797          74175642   4/25/1948   0.75  Female   2a_FO                 9.0
# 798          73408634  10/30/1949   1.00    Male   1a_FO                 7.0
# 799          73724718    5/7/1926   0.83    Male   2a_FO                 7.0
#
# [800 rows x 6 columns]

# %%
# explore the last 40 rows
df.tail(40)
# Out:
#                                      Patient Unique ID  Birth Date   PRS   \
# 804                                           73725470    5/4/1947   1.00
# 805                                           75289178   7/26/1932   1.00
# 806                                           74552346  12/22/1944   1.00
# 807                                           73715820   5/18/1943   0.40
# 808                                           73408136   8/18/1933   1.00
# 809                                           75360728  11/13/1934   1.00
# 810                                           75290656    4/3/1945   0.67
# 811                                           73002626   7/10/1937   0.91
# 812                                           72815440  10/11/1967   0.75
# 813                                           72815980   3/24/1953   1.00
# 814                                           74602268   10/2/1944   1.00
# 815                                           59702932   5/11/1959   0.97
# 816                                           73365132   6/30/1954   1.00
# 817                                           59946176   9/21/1955   0.93
# 818                                           60752962    1/6/1961   0.94
# 819                                           60644874   9/11/1964   0.93
# 820                                           59946104   9/11/1956   0.87
# 821                                           59958576  10/21/1962   0.71
# 822                                           63036160   6/13/1956   0.90
# 823                                           73671138   6/11/1984   1.00
# 824                                           61948538   5/10/1965   1.00
# 825                                           62429568   12/7/1977   0.67
# 826                                           66170394   6/13/1960   0.60
# 827                                           62477312   9/20/1952   0.88
# 828                                           62469208   5/28/1958   0.81
# 829                                           62469082    5/6/1955   0.94
# 830                                           62576768  10/25/1980   0.82
# 831                                           60810988    1/9/1955   0.63
# 832                                           60854146  12/30/1899   0.54
# 833                                           75769216    6/4/1964   1.00
# 834                                           71236110   1/28/1942   1.00
# 835                                           67896832  12/10/1957   0.80
# 836                                           67916806   2/15/1943   0.67
# 837                                           68082912   1/15/1945   1.00
# 838                                                NaN         NaN    NaN
# 839           Business Analyst Test -Tapestry data set         NaN    NaN
# 840  Copyright (c) 2000-2018 salesforce.com, inc. A...         NaN    NaN
# 841       Confidential Information - Do Not Distribute         NaN    NaN
# 842       Generated By: Alex Gerson 7/16/2018 11:39 AM         NaN    NaN
# 843                                             MedZed         NaN    NaN
#
#      Gender Subzone  Chronic Conditions
# 804    Male   1a_FO                 8.0
# 805    Male   1a_FO                 8.0
# 806    Male   1a_FO                 8.0
# 807  Female   2a_FO                 7.0
# 808    Male   1a_FO                 8.0
# 809    Male   1a_FO                 5.0
# 810    Male   2a_FO                 6.0
# 811  Female   2a_FO                 5.0
# 812    Male   2a_FO                 NaN
# 813    Male   3a_FO                 NaN
# 814  Female   4a_FO                 NaN
# 815  Female      5b                 2.0
# 816  Female      2a                 NaN
# 817  Female     2ax                 5.0
# 818    Male      1a                 3.0
# 819    Male      1c                 NaN
# 820  Female      1c                 1.0
# 821  Female      1d                 1.0
# 822  Female      1d                 1.0
# 823  Female      4a                 NaN
# 824    Male     2ax                 3.0
# 825    Male      2c                 NaN
# 826  Female      5b                 NaN
# 827  Female      1c                 1.0
# 828    Male      1a                 1.0
# 829  Female      3b                 3.0
# 830    Male      1b                 2.0
# 831  Female      1c                 4.0
# 832  Female      1c                 2.0
# 833    Male      1c                 NaN
# 834    Male   2a_FO                 NaN
# 835  Female      2a                 2.0
# 836    Male      3b                 NaN
# 837  Female      2a                 NaN
# 838     NaN     NaN                 NaN
# 839     NaN     NaN                 NaN
# 840     NaN     NaN                 NaN
# 841     NaN     NaN                 NaN
# 842     NaN     NaN                 NaN
# 843     NaN     NaN                 NaN

# %%
# quick look at all the info in this dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844 entries, 0 to 843
# Data columns (total 6 columns):
# Patient Unique ID     843 non-null object
# Birth Date            838 non-null object
#  PRS                  838 non-null float64
# Gender                838 non-null object
# Subzone               838 non-null object
# Chronic Conditions    438 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 39.7+ KB

# %%
# check for nan value
df.isnull().sum()
# Out:
# Patient Unique ID       1
# Birth Date              6
#  PRS                    6
# Gender                  6
# Subzone                 6
# Chronic Conditions    406
# dtype: int64

# %%
# quick look at statistical number for PRS & Chronic Conditions
df.describe()
# Out:
#              PRS   Chronic Conditions
# count  838.000000          438.000000
# mean     0.867100            4.940639
# std      0.181986            2.164016
# min      0.140000            0.000000
# 25%      0.750000            4.000000
# 50%      1.000000            5.000000
# 75%      1.000000            6.000000
# max      1.000000           10.000000

# %%
# drop nan values
df.dropna(subset=None,inplace=True)

# %%
df.isnull().sum()
# Out:
# Patient Unique ID     0
# Birth Date            0
#  PRS                  0
# Gender                0
# Subzone               0
# Chronic Conditions    0
# dtype: int64

# %%
# check df again after cleaning
df
# Out:
#     Patient Unique ID  Birth Date   PRS   Gender Subzone  Chronic Conditions
# 0            67130544   5/26/1974   0.70    Male      1d                 0.0
# 1            73838640   8/31/1924   1.00    Male   4a_FO                 5.0
# 2            73576382    2/8/1954   1.00  Female   2a_FO                 6.0
# 3            74030096   3/15/1934   1.00  Female   2a_FO                 6.0
# 4            73981356   5/18/1938   1.00  Female   2a_FO                 7.0
# ..                ...         ...    ...     ...     ...                 ...
# 829          62469082    5/6/1955   0.94  Female      3b                 3.0
# 830          62576768  10/25/1980   0.82    Male      1b                 2.0
# 831          60810988    1/9/1955   0.63  Female      1c                 4.0
# 832          60854146  12/30/1899   0.54  Female      1c                 2.0
# 835          67896832  12/10/1957   0.80  Female      2a                 2.0
#
# [438 rows x 6 columns]

# %%
df['Birth Date'].value_counts().sort_index()
# Out:
# 1/10/1933    1
# 1/10/1942    1
# 1/10/1944    1
# 1/11/1949    1
# 1/12/1944    1
#             ..
# 9/6/1953     1
# 9/7/1935     1
# 9/7/1939     1
# 9/7/1965     1
# 9/8/1941     1
# Name: Birth Date, Length: 430, dtype: int64

# %%
import datetime
date = datetime.date.today()
date
# Out:
# datetime.date(2020, 2, 22)

# %%
from datetime import datetime
df['Age'] = now - datetime.strptime(df['Birth Date'],'%m%d%y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-923e361ac768> in <module>
#       1 from datetime import datetime
# ----> 2 df['Age'] = now - datetime.strptime(df['Birth Date'],'%m%d%y')
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
# plot features distribution
fig=plt.figure(figsize=(20,20))
columns_list = df.columns 
# Create for loop to navigate through the column list
for i, feature in enumerate(columns_list):
    ax=fig.add_subplot(6,3,i+1)
    df[feature].hist(bins=20,ax=ax,facecolor='midnightblue')
    ax.set_title(feature+" Distribution", color='DarkRed')
        
fig.tight_layout()  
plt.show()

# %% [markdown]
# #### Quick Note
# * The patients in this dataset are very close in age
# * Most of the patients are likely to keep their appts (PRS=1)
# * Gender is equally distributed
# * Chronic Condition has somewhat of a bell shape - indicating normal distribution

# %%
# Attempting to find the relationship among attributes using heatmap
fig = plt.gcf()
fig.set_size_inches(18, 10)
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# ##### Note:
#  * Don't see any relationship here
