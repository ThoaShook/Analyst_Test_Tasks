# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
tasks = pd.read_csv('Analyst_Test_Tasks.csv')
tasks.head()
# Out:
#    Patient drchrono ID             Category    Status  Priority Assigned To  \
# 0             60094576  Specimen Collection  Complete        20  MOXXIadmin
# 1             59946176           Phone Call  Complete        20  MOXXIadmin
# 2             59740292           Phone Call  Complete        20  MOXXIadmin
# 3             60121538           Phone Call  Complete        20  MOXXIadmin
# 4             60121538                  NaN  Complete        20  MOXXIadmin
#
#             Created on    Create by           Updated on  \
# 0  2016-07-22T14:14:20  Neilsolomon  2018-03-28T21:14:32
# 1  2016-08-25T20:07:00        nsome  2018-03-28T21:14:32
# 2  2016-08-29T18:23:10        nsome  2018-03-28T21:14:32
# 3  2016-09-02T15:08:08        nsome  2018-03-28T21:14:32
# 4  2016-09-06T08:54:44        nsome  2018-03-28T21:14:32
#
#              Next Appt Date  HC20 Status          HC20 Substatus  \
# 0                       NaN          NaN                     NaN
# ...

# %%
tasks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3659 entries, 0 to 3658
# Data columns (total 13 columns):
# Patient drchrono ID      3659 non-null int64
# Category                 3445 non-null object
# Status                   3659 non-null object
# Priority                 3659 non-null int64
# Assigned To              3598 non-null object
# Created on               3659 non-null object
# Create by                2961 non-null object
# Updated on               3659 non-null object
# Next Appt Date           2411 non-null object
# HC20 Status              3646 non-null object
# HC20 Substatus           3646 non-null object
# Stratification level     621 non-null object
# Last Appointment Date    3659 non-null object
# dtypes: int64(2), object(11)
# memory usage: 371.7+ KB

# %%
tasks.isnull().sum()
# Out:
# Patient drchrono ID         0
# Category                  214
# Status                      0
# Priority                    0
# Assigned To                61
# Created on                  0
# Create by                 698
# Updated on                  0
# Next Appt Date           1248
# HC20 Status                13
# HC20 Substatus             13
# Stratification level     3038
# Last Appointment Date       0
# dtype: int64

# %%
tasks.shape
# Out:
# (3659, 13)

# %%
tasks.size
# Out:
# 47567

# %%
tasks['Status'].value_counts()
# Out:
# Complete       2773
# In Progress     633
# Open            153
# On Hold          58
# Authorized       39
# Back to PCP       3
# Name: Status, dtype: int64

# %%
tasks['Assigned To'].value_counts()
# Out:
# MOXXIadmin          2517
# suzztasharma         203
# gblandon             193
# marlenegarcia        163
# CareCoordinators     111
# pvallejo             109
# aarreola              92
# darzate               68
# aalmanza              17
# kelder                16
# mdavis07              15
# cmathews              11
# kapostol              11
# ebenons                9
# epopoca                8
# HRubin                 7
# stinajero              6
# Neilsolomon            5
# mduarte                4
# nsome                  4
# hcolomer               4
# ggardner               4
# hanzaldua              4
# AmandaMay              3
# egragnani              2
# mariadperez            2
# aglaros                1
# GFedalizo              1
# CSobrian               1
# mikejimenez            1
# CMiranda               1
# MyrnaGonzalez          1
# alexgerson             1
# cristianpacheco        1
# JessicaMejia           1
# DanaLewis              1
# ...

# %%
tasks_unfinished = tasks.loc[tasks['Status'] !='Complete']
tasks_unfinished
# Out:
#       Patient drchrono ID                 Category       Status  Priority  \
# 262              69026616                 Referral  In Progress        20
# 368              69321260  Medical Records Request      On Hold        20
# 377              68793552  Medical Records Request      On Hold        20
# 391              67917278  Medical Records Request  In Progress        20
# 427              70296028  Medical Records Request  In Progress        40
# ...                   ...                      ...          ...       ...
# 3653             72627908  Medical Records Request  In Progress        30
# 3655             59660512         Pharmacy Request         Open        20
# 3656             75868580               Phone Call         Open        20
# 3657             75752396                      DME         Open        20
# 3658             72722878         Pharmacy Request         Open        20
#
#            Assigned To           Created on   Create by           Updated on  \
# ...

# %%
CareCoordinator_names = ['Aarreola', 'Pvallego','marlenegarcia','suzztashrma','CareCoordinators','darzate','gblandon']
tasks_unfinished_coordinators = tasks_unfinished['Assigned To'] =='CareCoordinator_names')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-661334e40862> in <module>
#       1 CareCoordinator_names = ['Aarreola', 'Pvallego','marlenegarcia','suzztashrma','CareCoordinators','darzate','gblandon']
# ----> 2 tasks_unfinished_coordinators = tasks_unfinished.groupby('CareCoordinator_names')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ...

# %%
tasks['Create by'].value_counts()
# Out:
# dyousef          829
# nsome            718
# Neilsolomon      471
# HRubin           246
# gblandon         188
# vzuniga          102
# kelder            80
# suzztasharma      64
# ggardner          49
# aalmanza          24
# pvallejo          24
# jtulsky           23
# cmathews          22
# egragnani         21
# aarreola          20
# marlenegarcia     18
# dmshuster         10
# MyrnaGonzalez      8
# AmandaMay          8
# hcolomer           7
# darzate            7
# epopoca            6
# NeoldinoPapa       4
# KDouglas           3
# HSchade            2
# hanzaldua          2
# mduarte            1
# alexgerson         1
# hopejavier         1
# kapostol           1
# ebenons            1
# Name: Create by, dtype: int64

# %%
tasks['Category'].value_counts()
# Out:
# Referral                   1199
# Phone Call                  667
# Medical Records Request     437
# DME                         280
# Pharmacy Request            263
# Lab Results                 217
# Social Services             151
# Supplies                     83
# Specimen Collection          64
# Behavioral Health            48
# Transportation               36
# Name: Category, dtype: int64

# %%
tasks.rename(columns={'Created on':'Created_on'})
# Out:
#       Patient drchrono ID             Category    Status  Priority  \
# 0                60094576  Specimen Collection  Complete        20
# 1                59946176           Phone Call  Complete        20
# 2                59740292           Phone Call  Complete        20
# 3                60121538           Phone Call  Complete        20
# 4                60121538                  NaN  Complete        20
# ...                   ...                  ...       ...       ...
# 3654             74177154     Pharmacy Request  Complete        20
# 3655             59660512     Pharmacy Request      Open        20
# 3656             75868580           Phone Call      Open        20
# 3657             75752396                  DME      Open        20
# 3658             72722878     Pharmacy Request      Open        20
#
#            Assigned To           Created_on    Create by           Updated on  \
# 0           MOXXIadmin  2016-07-22T14:14:20  Neilsolomon  2018-03-28T21:14:32
# ...

# %%
#tasks.groupby('Category').agg(mean_Status = ('Status'=='Complete','mean')).round(-3)
